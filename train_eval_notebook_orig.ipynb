# %%
import lyrics_scraper
import os
import time
import datetime


import pandas as pd
import seaborn as sns
import numpy as np
import random

import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader, random_split, RandomSampler, SequentialSampler
torch.manual_seed(42)

from transformers import GPT2LMHeadModel,  GPT2Tokenizer, GPT2Config
from transformers import AdamW, get_linear_schedule_with_warmup
# Out:
# 141

# %%
data = lyrics_scraper.retrieve_lyrics()
lyrics = data.lyrics_col.copy()

song_lengths = []

for song in lyrics:
    tokens = nltk.word_tokenize(song)
    song_lengths.append(len(tokens))

song_lengths = np.array(song_lengths)

sns.histplot(song_lengths)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
len(song_lengths[song_lengths > 768])/len(song_lengths)
# Out:
# 0.3788457671425699

# %%
np.average(song_lengths)
# Out:
# 720.8162075206113

# %%
# Load the GPT tokenizer.
tokenizer = GPT2Tokenizer.from_pretrained('gpt2', bos_token='<|startoftext|>', eos_token='<|endoftext|>', pad_token='<|pad|>') #gpt2-medium
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embedding are fine-tuned or trained.

# %%
print("The max model length is {} for this model, although the actual embedding size for GPT small is 768".format(tokenizer.model_max_length))
print("The beginning of sequence token {} token has the id {}".format(tokenizer.convert_ids_to_tokens(tokenizer.bos_token_id), tokenizer.bos_token_id))
print("The end of sequence token {} has the id {}".format(tokenizer.convert_ids_to_tokens(tokenizer.eos_token_id), tokenizer.eos_token_id))
print("The padding token {} has the id {}".format(tokenizer.convert_ids_to_tokens(tokenizer.pad_token_id), tokenizer.pad_token_id))
# Out:
# The max model length is 1024 for this model, although the actual embedding size for GPT small is 768
# The beginning of sequence token <|startoftext|> token has the id 50257
# The end of sequence token <|endoftext|> has the id 50256
# The padding token <|pad|> has the id 50258

# %%
batch_size = 1

# %%
class GPT2Dataset(Dataset):

  def __init__(self, txt_list, tokenizer, gpt2_type="gpt2", max_length=768):

    self.tokenizer = tokenizer
    self.input_ids = []
    self.attn_masks = []

    for txt in txt_list:

      encodings_dict = tokenizer('<|startoftext|>'+ txt + '<|endoftext|>', truncation=True, max_length=max_length, padding="max_length")

      self.input_ids.append(torch.tensor(encodings_dict['input_ids']))
      self.attn_masks.append(torch.tensor(encodings_dict['attention_mask']))
    
  def __len__(self):
    return len(self.input_ids)

  def __getitem__(self, idx):
    return self.input_ids[idx], self.attn_masks[idx]

# %%
dataset = GPT2Dataset(lyrics, tokenizer, max_length=768)

# Split into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

print('{:>5,} training samples'.format(train_size))
print('{:>5,} validation samples'.format(val_size))
# Out:
# 4,475 training samples
#   498 validation samples

# %%
print (type(dataset))
# Out:
# <class '__main__.GPT2Dataset'>

# %%
# Create the DataLoaders for our training and validation datasets.
# We'll take training samples in random order. 
train_dataloader = DataLoader(
            train_dataset,  # The training samples.
            sampler = RandomSampler(train_dataset), # Select batches randomly
            batch_size = batch_size # Trains with this batch size.
        )

# For validation the order doesn't matter, so we'll just read them sequentially.
validation_dataloader = DataLoader(
            val_dataset, # The validation samples.
            sampler = SequentialSampler(val_dataset), # Pull out batches sequentially.
            batch_size = batch_size # Evaluate with this batch size.
        )

# %%
# I'm not really doing anything with the config buheret
configuration = GPT2Config.from_pretrained('gpt2', output_hidden_states=False)

# instantiate the model
model = GPT2LMHeadModel.from_pretrained("gpt2", config=configuration)

# this step is necessary because I've added some tokens (bos_token, etc) to the embeddings
# otherwise the tokenizer and model tensors won't match up
model.resize_token_embeddings(len(tokenizer))

# Empty cache
torch.cuda.empty_cache()

# Tell pytorch to run this model on the GPU.
device = torch.device("cuda")
model.cuda()
# Set the seed value all over the place to make this reproducible.
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
# some parameters I found that work reasonably well

epochs = 5
learning_rate = 2e-5
warmup_steps = 1e2
epsilon = 1e-8

# this produces sample output every 100 steps
sample_every = 100

# %%
# Note: AdamW is a class from the huggingface library (as opposed to pytorch) 
optimizer = AdamW(model.parameters(),
                  lr = learning_rate,
                  eps = epsilon
                )

# %%
# Total number of training steps is [number of batches] x [number of epochs]. 
# (Note that this is not the same as the number of training samples).
total_steps = len(train_dataloader) * epochs

# Create the learning rate scheduler.
# This changes the learning rate as the training loop progresses
scheduler = get_linear_schedule_with_warmup(optimizer, 
                                            num_warmup_steps = warmup_steps, 
                                            num_training_steps = total_steps)

# %%
def format_time(elapsed):
    return str(datetime.timedelta(seconds=int(round((elapsed)))))

# %%
total_t0 = time.time()
training_stats = []

model = model.to(device)

for epoch_i in range(0, epochs):

    # ========================================
    #               Training
    # ========================================

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    t0 = time.time()

    total_train_loss = 0

    model.train()

    for step, batch in enumerate(train_dataloader):

        b_input_ids = batch[0].to(device)
        b_labels = batch[0].to(device)
        b_masks = batch[1].to(device)

        model.zero_grad()        

        outputs = model(  b_input_ids,
                          labels=b_labels, 
                          attention_mask = b_masks,
                          token_type_ids=None
                        )

        loss = outputs[0]  

        batch_loss = loss.item()
        total_train_loss += batch_loss

        # Get sample every x batches.
        if step % sample_every == 0 and not step == 0:

            elapsed = format_time(time.time() - t0)
            print('  Batch {:>5,}  of  {:>5,}. Loss: {:>5,}.   Elapsed: {:}.'.format(step, len(train_dataloader), batch_loss, elapsed))

            model.eval()

            sample_outputs = model.generate(
                                    bos_token_id=random.randint(1,30000),
                                    do_sample=True,   
                                    top_k=50, 
                                    max_length = 200,
                                    top_p=0.95, 
                                    num_return_sequences=1
                                )
            for i, sample_output in enumerate(sample_outputs):
                  print("{}: {}".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
            
            model.train()

        loss.backward()

        optimizer.step()

        scheduler.step()

    # Calculate the average loss over all of the batches.
    avg_train_loss = total_train_loss / len(train_dataloader)       
    
    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epoch took: {:}".format(training_time))
        
    # ========================================
    #               Validation
    # ========================================

    print("")
    print("Running Validation...")

    t0 = time.time()

    model.eval()

    total_eval_loss = 0
    nb_eval_steps = 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:
        
        b_input_ids = batch[0].to(device)
        b_labels = batch[0].to(device)
        b_masks = batch[1].to(device)
        
        with torch.no_grad():        

            outputs  = model(b_input_ids, 
#                            token_type_ids=None, 
                             attention_mask = b_masks,
                             labels=b_labels)
          
            loss = outputs[0]  
            
        batch_loss = loss.item()
        total_eval_loss += batch_loss        

    avg_val_loss = total_eval_loss / len(validation_dataloader)
    
    validation_time = format_time(time.time() - t0)    

    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))

    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )

print("")
print("Training complete!")
print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# t, I know, it's gon' be alright
# I’m bein’ in this one, it's gon' be alright
# I'ma keep my chest up, it's gon' be alright
#
#
# It's gon’ be alright, I know, it's gon' be alright
# I'ma put your shoulder on top, that's just another one
# I'll make you take your hand off, make you take your hand off
# And it's gonna be alright, I know,
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 1,700  of  4,475. Loss: 2.516315460205078.   Elapsed: 0:05:45.
# 0:  Laure
# Oh
# I'm really feeling out here but still you know my love, it's so amazing
# We all feel in this relationship, every day we feel in a relationship, you just gotta feel the love
# So that it feels real, that it felt real so let it be, a little bit
#
# The only thing I miss with the city of God is some sense of peace
# The only thing that I miss with the city of God is some sense of peace
# The only thing that I miss with the city of God is some sense of peace
#
# We are a living planet, a living star
# And you should not think about that
# Why should the stars tell you that?
# Maybe we will live on and grow with peace
# Or maybe we will die and die and die
# Maybe you will never see us again, maybe someday, maybe someday
# We will never be peace, maybe someday
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 1,800  of  4,475. Loss: 2.4721462726593018.   Elapsed: 0:06:06.
# 0: ism
# Yo!
# If I wanna take it from the ghetto, you gotta do somethin' (What?), yeah, we gon' do somethin' (That?), yeah, we gotta do somethin'
#
# I wanna take it from the ghetto, that nigga is badder than a cop
# Bitch, why don't I pull your shirt down like I'm in a Porsche coupe
# And don't you see it? Well
# I know you got some bad guys out there who don't understand how to handle a nigga that's a bitch, that nigga, this nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga, that nigga
# I ain't trippin' that bitch up, she tryna cut the grass in her ass
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 1,900  of  4,475. Loss: 2.0691378116607666.   Elapsed: 0:06:26.
# 0: oun
# You lookin' good
# We got two cups of the juice
# Got me some kush, got me some kush
# Got me some kush
# Got me some kush
# Got me some kush
# Got me some kush
# Got me some kush
# Yeah, ayy
#
# Hey, hey
#
# I got a friend, my bitch
# Hey, hey
# We got two cups of the juice
# Got me some kush
# Got me some kush
# Got me some kush
#
# Got me a cup of the juice?
#
# Bitches need a cup of the juice
# Bitches need a cup of the juice
# Bitches need a cup of the juice
# Bitches need a cup of the juice
#
# I don't care how good you are
#
# Bitches need a cup of
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,600  of  4,475. Loss: 2.157970666885376.   Elapsed: 0:08:49.
# 0:  reproductive
# Took a bus down Broadway all night, I never heard the police get in in
# Took a bus down Broadway all night, I never heard the police get in
# That ain't right, that don't mean that I can't do that
# That ain't the problem with this lifestyle I started back in the days
# Took a bus down Broadway all night, I never heard the police get in
# Took a bus down Broadway all night, I never heard the police get in
# That ain't the problem with this lifestyle I started back in the days
# Took a bus down Broadway all night, I never heard the police get in
# That ain't the problem with this lifestyle I started back in the days
# Took a bus down Broadway all night, I never heard the police get in
# That ain't the problem with this lifestyle I started back in the days
# Took a bus down Broadway all
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,700  of  4,475. Loss: 3.320810079574585.   Elapsed: 0:09:10.
# 0:  zone
# Yeah
#
# This life is a maze, oh, I wonder what I'm doing next
# How I want to win? (I know)
# I want to reach that heaven, this where you're buried in
# That I'm afraid of
# The world is a maze, oh, I wonder what I'm doing next
# How I want to win?
#
# I don't want this life, I want this one
# Ain't got a clue what I'm doing, I want this one
# I want this life, I want this one
# I want this life, I want this one
# And I want this life, I want this one
#
# It's gon' be alright, it won't be alright
# Just let this life go, and let the world go
# I'll be here in that dream, I won't let a life go
# I'll be there
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,800  of  4,475. Loss: 3.224846601486206.   Elapsed: 0:09:30.
# 0:  commits
# The game is just a maze of different niggas you can fuck around with
# I'm only fucking once, this ain't no discussion
# They say I'm really cool cause I'm real
# I know the world is yours, my flow is just a maze
# I'm just doing it for me
#
# You already know what my life is, I will never go back to what I was, I did it for ya
# I ain't have to hide what I did, just show my love
# I've been through a lot but I feel lost
# I think back on all the things that I went through
# I thought I was so fine, but I felt real
# I thought I was fine, but I felt real
# I thought I was fine, but I felt real
# I thought I was fine, but I felt real
# I thought I was fine, but I felt real
# I
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,900  of  4,475. Loss: 3.3960366249084473.   Elapsed: 0:09:51.
# 0:  irony
# Yeah
# Came up on a different day, that ain't about to stop
# A day later, there's one still
# A day later, that's not about to stop
# 'Cause I'm feeling up at night
# Yeah
# I don't give a fuck 'cause that shit gettin' complicated
# Got a few years left
# She said I'm just tired of her
# But I just wanna let her know, so we can solve it right
# I'll take a trip to the mall for the summer and I might pick up the phone
# If there's nothing that you can do for me, maybe we can get more
# If everything that I'm doing is fine and good and good and good and great
# I just wanna let her know
# You're still waiting on some paper that we can solve it
# I've been busy so I can be on her mind
#
# Yeah
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,000  of  4,475. Loss: 1.6082772016525269.   Elapsed: 0:10:12.
# 0:  Sah
# No, I don't want no sex but I'll be damned if I don't be faithful
# Towards the age of twenty-five, my mind is spinning on the same beat I'm rapping on
# I don't want to be alone but I'll be damned if I don't be faithful
# A nigga ain't got a problem with no help and he's gon' get me worse
# It's just an excuse to act like I'm stupid
# A nigga got a problem with no help and he's gon' get me worse
# It's just an excuse to act like I'm stupid
# A nigga ain't got a problem with no help and he's gon' get me worse
# It's just an excuse to act like I'm stupid
# A nigga ain't got a problem with no help and he's gon' get me worse
# It's just an excuse to act like I'm
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,700  of  4,475. Loss: 2.547679901123047.   Elapsed: 0:12:35.
# 0: ruce
# The truth is we have a problem, people don’t want it at all
# But then we go and have our babies, there’s nothing left
# We’re all born from a mother's mouth, this’s an opportunity for everybody to get it at all
# It’s a choice we get to make, ’we’re all born,’ we’re all born,’ we’re all born from a mother’ mouth,’ it’s an opportunity to get it at all
# It’s a choice we get to make,’we’re all born,’ we’re all born,’ we’re all born from a mother� mouth,� it’s an opportunity to get it at all
# It’s a choice we get to make,’we’re all
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,800  of  4,475. Loss: 3.124504327774048.   Elapsed: 0:12:55.
# 0:  derivatives
# Dee, who don't believe ya?
# Shout to this bitch, I bet she'll get you (Dee, man)
#
# I used to smoke in the car (I used to smoke at the crib)
# I used to play in the club (I used to play with that)
# I had to make some more noise than the fakers (I used to talk the louder, make sure you know
# Shed on my neck, you couldn't fit)
# You want me, just to feel me (What? What? What? What? What, what?), we gon' take care of it (Take care of it)
# I used to write the song, I wrote the melody (Haha)
# I used to be down when I left (Yeah, yeah, yeah, yeah, yeah, yeah)
# 'Cause, if she hit it, they gon' tell her that
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,900  of  4,475. Loss: 2.958861827850342.   Elapsed: 0:13:17.
# 0:
# I'm with my baby daddy.
# I'm with my mom
# I'm with my mom
# I'm with my mom
# I'm with my mom
#
# I'm with my daddy
# I'm with my mom
# I'm with my mom
# I'm with my mom
# I'm with my mom
#
# You're mine, so I can fuck your motherfucking soul
# You're mine, so I can fuck your momfucking soul
# I'm with my mama, so I can fuck your motherfucking soul
#
# I'm with my sister, I know you ain't the one I wanted you to go to college
# I ain't tryna talk to you, I'm trying to find your moms
# But I know you ain't the one I wanted you to go to college
# I ain't tryna talk to you, I'm trying to find
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,000  of  4,475. Loss: 2.057574987411499.   Elapsed: 0:13:38.
# 0:  remembering
# So many people in my hood know
#
# And I know they know (Ya know?)
# But, they know they know
# Ya know they know
#  (Ya know)
# So many people in my hood know
# I know they know, 'cause I know (Ya know?)
#
# I, I had to go
# You were my first love, nigga
# So many people in my hood know
#
# I know they know
# But, they know
# And I know they know (Ya know?)
# But, they know (Ya know?)
#
# I know they know
# They know
#
# But, they know (Ya know?)
#
# But, they know (Ya know)
# Oh, oh, oh, oh
#
# You said so many things, lil' lil' nigga
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,100  of  4,475. Loss: 3.834716558456421.   Elapsed: 0:13:58.
# 0:  Sources
# Yeah, I be riding with my mama
# Gonna leave ya for a second, you might start to feel like I'm just a little old
# You can't tell me you gon' see you there
# That I'm just a little old, I can't tell you not
# And the future is bright, see you in it, and you can't tell me that I hate you
# 'Cause I just be riding with my mama
# Gonna leave ya for a second, you might start to feel like I'm just a little old
# You can't tell me you gon' see you there
# That I'm just a little old, I can't tell you not
# And the future is bright, see you in it, and you can't tell me that I hate you
# 'Cause I just be riding with my mama
#
# Birds, you do you right
# They always try
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,200  of  4,475. Loss: 3.3852388858795166.   Elapsed: 0:14:19.
# 0: ems
# All I care about is money
# What I’m on is cash
# And you’ve got the other one, ho
# Yeah, yeah, yeah
# All I care about is money
# What I’m on is cash
# And you’ve got the other one, ho
# Yeah, yeah, yeah
# All I care about is money
# What I’m on is cash
# And you’ve got the other one, ho
# Yeah, yeah, yeah
# All I care about is money
# What I’m on is cash
# And you’ve got the other one, ho
# Yeah, yeah, yeah
# All I care about is money
# What I’m on is money
# What I’m on is money
# What I’m on is cash
# And you’ve got the
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,300  of  4,475. Loss: 2.8359596729278564.   Elapsed: 0:14:40.
# 0: tz
# Yeah, yeah
# Yeah, yeah
# Yeah, yeah
#
# Wake up in that Mercedes, that Lam truck, I'm just doing my damn thing
# Woke up in that Lam truck, this Lam truck, I'm just doing my damn thing
# Woke up in that Lam truck, this Lam truck, I'm just doing my damn thing
# Wake up in that Lam truck, that Lam truck, I'm just doing my damn thing
# Woke up in that Lam truck, this Lam truck, I'm just doing my damn thing
# Woke up in that Lam truck, this Lam truck, I'm just doing my damn thing
# Woke up in that Lam truck, this Lam truck, I'm just doing my damn thing
#
# I'm a young nigga but I'm still getting paid
# I got money, but they don't want shit
# You say it, but
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,400  of  4,475. Loss: 4.757668495178223.   Elapsed: 0:15:00.
# 0: matic
# (Hey)
# I'm the one you need, now, baby
# I'm the one you need, baby, yeah
# (Hey)
# 'Cause you know I'ma kill your face today
# 'Cause you know I'ma kill your face today
#
# I'ma kill your face today (Yeah)
#
# You wanna be an ode, my nigga
# I kill your face today
# You wanna be an ode, my nigga
# I kill your face today
#
# You wanna be an ode, my nigga
# I kill your face today (Yeah)
#
# 'Cause you know I'ma kill your face today (Yeah)
# 'Cause you know I'ma kill your face today
#
# I wanna kill your face today (Yeah)
#
# You wanna be an ode, my nigga
# I
#
#   Average training loss: 3.03
#   Training epoch took: 0:15:16
#
# Running Validation...
#   Validation Loss: 2.71
#   Validation took: 0:00:29
#
# ======== Epoch 2 / 5 ========
# Training...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch   100  of  4,475. Loss: 1.7239017486572266.   Elapsed: 0:00:19.
# 0:  synd
# Let me set me a little up
# Let me break off on 'em and walk it through
# Let me show you how to do what we got
# Let me show you how to do what we got
# I'm really starting to get into that
# If I was to fall through
# I'd think it was my time to pick cotton
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
# I'm really starting to get into that
#
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch   200  of  4,475. Loss: 3.1680920124053955.   Elapsed: 0:00:40.
# 0:  gam
# Yeah, yeah, yeah, yeah, yeah, yeah
# I'm that motherfucker! (Ha, ha)
# I'm that motherfucker!
# I got some motherfucker! (Ha, ha)
# I'm that motherfucker! (Ha, ha)
# I'm that motherfucker!
# I got some motherfucker! (Ha, ha)
#
# She's on the beat like I'm Mike (Ha)
# I'm 'bout to blow up (Ha)
# I'm 'bout to blow up (Ha)
# I'm 'bout to blow up (Ha)
# I'm 'bout to blow up (Ha)
# I'm 'bout to blow up (Ha)
# I'm 'bout to blow up (Ha)
# I'm 'bout to blow up (Ha)
# I'm '
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Bat
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch   800  of  4,475. Loss: 2.668303966522217.   Elapsed: 0:02:48.
# 0:  purch
# Uh, uh
# Uhh, uh
#
# Uhh, uh, uh
# Uh
# Yeah, you know the fuck is I'm talkin' back?
# Uhh, uh
# Yeah, you know the fuck is I'm talkin' back? (Uh)
# Uh, uhh, uh
# I said the fuck is I'm talkin' back?
# Uh, uh uh, uh (Yeah)
# It's back for the baddest youngin, the dopest nigga, in the game
# I just wanna see if you really want it (Uhh)
# Uhh, uh uh-uh, uh
# Uh
# Yeah, you know the fuck?
# Uh, uh, yeah
# Yeah, you can't walk me off with a limp
# They're talkin' back
# Yeah, we a fuckin' bunch of fuckin' lame,
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch   900  of  4,475. Loss: 3.0454680919647217.   Elapsed: 1:03:46.
# 0:  shoulders
# Ladies and gentlemen
# This is dedicated to the nameless
# C'mere, for my niggas in the industry
# I'm a menace, a killer, a threat
# My flow is deadly
# When I do I leave you paralyzed
# In denial, if you ain't listening
# In denial, this is for you to listen to
# I will be nothing but dead
#
# I'm the villain, the villain will be everywhere when you wake
# I'm a menace, the villain will be everywhere when you wake
# Like a newborn in the womb
# And I be the villain, and it be everywhere
# Every day we're all about to die
# Every single day that I wake, and I can't lie
# I be the villain, and it be everywhere
# Every single day that I wake, and I can't lie
# Like the villain is a villain, and it be
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 1,000  of  4,475. Loss: 3.4977364540100098.   Elapsed: 1:04:08.
# 0:  built
# We don't know the outcome, we just know we gonna win (Win)
# Yeah
# Yeah
# We don't know the outcome, we just know we gonna win (Don't lose, yeah)
# Yeah
# Yeah, okay, okay, cool, cool (Uh-huh, okay, okay)
# Alright, alright, okay, okay, okay (Okay, okay, okay)
# Alright, alright, okay, okay (Uh, okay, okay, okay)
# Alright, alright, okay, okay (Yeah, okay, okay, okay)
#
# I got a couple things on my mind
# A couple bad hoes to put it on (What, uh?)
# A couple bad hoes to put it on (What, uh?)
# A couple bad hoes to put it on (What, uh?)
# A couple bad hoes to put it on (What, uh
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 1,100  of  4,475. Loss: 2.083388566970825.   Elapsed: 1:04:30.
# 0:  openly
# All I know is I can be here...
# Please be patient, son...
# It's too late...
#
# Tell you...
# You need a man...
# And that means it's too late...
#
# Life's like a song...
# Life is like a song...
# Life is like a song...
#
# Life is like a song...
# Life is like a song...
# Life is like a song...
#
# Life is like a song...
# Life is like a song...
#
# Life's like a song...
# Life is like a song...
# Life is like a song...
#
# Life is like a song...
# Life is like a song...
# Life is like a song...
#
# Life is like a song...
# Life is like a song...
# Life is like a song...
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# in the topin the track
# I just
# Got
# If we can't be cool?
# We got me is the hood, yeah
# A man
# You should really in the sun, a room with the weather, I know? I don't take it's got more
#
# Oh, fuck
# I had a better believe if
#
#
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,300  of  4,475. Loss: 2.7219085693359375.   Elapsed: 1:08:47.
# 0:  host-
#
#
# Yo, yo, yo
# I'm like, hey, hey, hey, hey, hey, hey
# Hey
# Now they're looking at me like, hey, hey
# I'm like, hey
# Now I'm like, hey, hey
# Hey, hey, hey, hey
# Now I'm like, hey, hey, hey
# Now I'm like, hey
# Hey, hey, hey, hey
# Hey, hey, hey, hey
# Now, hey, hey, hey
# Now I'm like, hey
# Hey, hey, hey, hey
# Now, hey, hey, hey, hey
# Hey, hey, hey, hey
#
# Hitch, yeah, hey, hey, hey
# Look
#
# Look at me like, hey, hey
# Now I'm like, hey, hey, hey, hey
#
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,400  of  4,475. Loss: 2.7863028049468994.   Elapsed: 1:09:07.
# 0: role
#
#
# That we ain't in no field with no wins, no wins, no wins, no wins
# We're not no one, we ain't scared from them, no wins
# We're no one, we ain't scared of them, no wins
# We're no one, we ain't scared of them, no wins
# We're no one, we ain't scared from them, no wins
# We're no one, we ain't scared of them, no wins
# We're no one, we ain't scared from them, no wins
# We're no one, we ain't scared of them, no win
# We're no one, we ain't scared of them, no wins
#
# We're no one, we ain't scared of them, no wins
# We're no one, we ain't scared of them, no wins
# We're no one, we ain't scared of them
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,500  of  4,475. Loss: 2.570479393005371.   Elapsed: 1:09:28.
# 0: iac
# ThisThis is another one, one, one
# Another one, two, three, four, but, five, five, five, five, five, five, five, five, five, five, five, five, five, five, five, five, five)
# This is another one, one
# Another one, one, one, a, two, two, two, let's go
# This is another one, one, a, two, let's go
#
#
# In this song and the crowd in every single moment
#
# The crowd is looking for a man who is a man, who is a man
# In a world where only a man made one
# This is another one, one, one, two, let's go
# This is another one, one, one, another one, let's go
# Yeah, yeah, yeah, go
# This is another one, one
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,600  of  4,475. Loss: 3.753535032272339.   Elapsed: 1:09:49.
# 0:  LD
# Yo, what's that good nigga? He got it, he got it (Yeah, he got it)
# We had nothing on our team, we had no choice, we had two choices (Yeah)
# It was something that you just couldn't see, it was something about the way we was playing. I wasn't like a man, I had to go and get more people to do what I wanted. We was the same, we had each other, the only time we had each other (Yeah)
# We was the same, we had each other, the only time we had each other (Yeah)
# I've had a lot things, I've been through a lot (Yeah)
# Some things I've been through (Yeah)
# Some things I've been through (Yeah)
# Some things that I've been through (Yeah)
#
# Some things I've been through (Yeah)
# Some
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,700  of  4,475. Loss: 1.917628526687622.   Elapsed: 1:10:09.
# 0:  ListenYo
# Bitch, you ain't gotta worry, bitch
# Bitch, I'ma hit these bitches on my finger
# I ain't even gotta say it loud, bitch
# Bitch, I'ma hit these bitches on my finger
# I ain't even gotta say it loud, bitch
# Bitch, I'ma hit these bitches on my finger
# I ain't even gotta say it loud, bitch
# Bitch, I'ma hit these bitches on my finger
# I ain't even gotta say it loud, bitch
# I ain't even gotta say it loud, bitch
# Bitch, I'ma hit these bitches on my finger
# I ain't even gotta say it loud, bitch
# Bitch, I'ma hit these bitches on my finger
# I ain't even gotta say it loud, bitch
# I ain't even gotta say it loud, bitch
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,800  of  4,475. Loss: 3.1849124431610107.   Elapsed: 1:10:29.
# 0:  dy
#
# Bitch, I wanna go outside
# Shout out to the world
# My niggas gettin' money, I be in love, so fuck all my brothers
# I don't have no money, but I won't run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run, but I'll run
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 2,900  of  4,475. Loss: 3.2195799350738525.   Elapsed: 1:10:49.
# 0:  Domestic
# And you got no choice
# If you want to know I am the best I know
# You get my number, it's my time
# I will not call this shit
# But you not with a phone to call you
# I'll never call it, but you not with my eyes
# So tell me you want some time to come and go, you can have the time
#
# Ayy, my life like a movie
# I don't care how you try to find it
# We just watchin', ayy, ayy, watchin'
# I don't care who they know at the time, it's gon' hit
# When we see the time, we'll watch it, like
#
# Oh, that's a whole other experience
# You say we don't, think we don't want that
# You want that, think we want that
# And you got no choice
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,000  of  4,475. Loss: 2.1711277961730957.   Elapsed: 1:11:09.
# 0:  beneficiaries
# I said, "Why you so fuckin' up?",
# I said, "I'm just talkin' shit in these 'Rari seats"
# Yeah, I said what? I said, "Why you so fuckin' up?",
# I said, "I'm just talkin' shit in these 'Rari seats"
# Yeah, I said what? I said, "Why you so fuckin' up?",
# I said, "I'm just talkin' shit in these 'Rari seats"
# Yeah, I said what? I said, "Why you so fuckin' up?"
#
# You the nigga, it's the baddest nigga, it's the baddest nigga
# I said, "Why you so fuckin' up?"
# I said, "I'm just talkin' shit in these 'Rari seats"
# Yeah, I said what? I said, "
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,100  of  4,475. Loss: 1.8293840885162354.   Elapsed: 1:11:28.
# 0:  Title
# The music was fantastic
# And I had to go home to make a few of my babies
# But the music wasn't great, it wasn't great
# I had to come back, leave me to find a couple of my old folks
# And one of the things I'm missing is the time I was thirteen
# But I had to go home and make a couple of my babies
#
# Now my brother's dead, I had to go out to be some friends
# I lost my brother, but I had to go get some friends
# And they had to stay to get some friends
# They took my brother, they had to stay to get some friends
# And they had to stay to get some friends
#
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 3,200  of  4,475. Loss: 2.5179665088653564.   Elapsed: 1:11:48.
# 0:  μ
# If you don't know who you are, you're not
# You're not, you're not
# You're not, you're not
# You're not, you're not, you're not
# You're not, you're not, you're not
#
# I'm outta here to fuck with my mom and my grandma
# Because of the way I look
# They think that I'm a queen but I'm not
# So I take my time and count my blessings
# If the truth is truth then I keep taking away from the devil
# But I'm just an orphan at 11
# I need to take my time
# Cause if I don't fuck with my dad I'm not a soldier
# To be honest with the devil can only suck a bitch and still suck
# So I keep taking my time
# Cause if I didn't fuck with my dad I'm not a soldier
# To
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,300  of  4,475. Loss: 2.2989795207977295.   Elapsed: 0:14:32.
# 0:  frontier
# Yeah, I feel like I'm trapped inside of my cell
# Waitin' for me to open up this box and tell me how to treat myself
# Inside this box, where I know I don't belong, I'm trapped inside this cell
# I feel like I'm trapped inside my cell
# Waitin' for me to open up this box and tell me how to treat myself
# Inside this box, where I know I don't belong, I'm trapped inside this cell
#
# I never sleep on silk covers
# I never sleep on silk covers
# I never sleep on silk covers
# I never sleep on silk covers
#
# In my box, where I know I don't belong, I'm trapped inside this cell
# I feel like I'm trapped inside this cell
# Waitin' for me to open up this box and tell me how to treat myself
# Inside this box, where I know I
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
#   Batch 4,400  of  4,475. Loss: 1.8376513719558716.   Elapsed: 0:14:51.
# 0:  atmospheric
# R.I.P. to Nate Dogg:
# "We at the OutKast in this bitch, right now, right now. We gonna kill your ass."
# (Shot fired)
# When you hear this new shit you be like (uh)
# Like I ain't never shot shit:
# Nah! (Shot fired)
# When you hear this new shit you be like (uh)
# Like I ain't never shot shit:
# Nah! (Shot fired)
#
# Ayo! Ayo! (Uh) I ain't never shot shit:
# Like I ain't never shot shit:
# Nah, like I ain't never shot shit
# Straight from the heart! (Uh)
# I'm the truth, nigga (Uh), straight from the gutter
# Hunnid round choppin' shit when my shit be spittin'
#
#   Average training loss: 1.88
#   Training epoch took: 0:15:06
#
# Running Validation...
#   Validation Loss: 2.83
#   Validation took: 0:00:27
#
# Training complete!
# Total training took 2:18:56 (h:mm:ss)

# %%
# Display floats with two decimal places.
pd.set_option('precision', 2)

# Create a DataFrame from our training statistics.
df_stats = pd.DataFrame(data=training_stats)

# Use the 'epoch' as the row index.
df_stats = df_stats.set_index('epoch')

# A hack to force the column headers to wrap.
#df = df.style.set_table_styles([dict(selector="th",props=[('max-width', '70px')])])

# Display the table.
df_stats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-589494a7c983> in <module>
#       3
#       4 # Create a DataFrame from our training statistics.
# ----> 5 df_stats = pd.DataFrame(data=training_stats)
#       6
#       7 # Use the 'epoch' as the row index.
#
# NameError: name 'training_stats' is not defined

# %%
# Use plot styling from seaborn.
sns.set(style='darkgrid')

# Increase the plot size and font size.
sns.set(font_scale=1.5)
plt.rcParams["figure.figsize"] = (12,6)

# Plot the learning curve.
plt.plot(df_stats['Training Loss'], 'b-o', label="Training")
plt.plot(df_stats['Valid. Loss'], 'g-o', label="Validation")

# Label the plot.
plt.title("Training & Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.xticks([1, 2, 3, 4])

plt.show()

# %%
# Get all of the model's parameters as a list of tuples.
params = list(model.named_parameters())

print('The GPT-2 model has {:} different named parameters.\n'.format(len(params)))

print('==== Embedding Layer ====\n')

for p in params[0:2]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== First Transformer ====\n')

for p in params[2:14]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))

print('\n==== Output Layer ====\n')

for p in params[-2:]:
    print("{:<55} {:>12}".format(p[0], str(tuple(p[1].size()))))
# Out:
# The GPT-2 model has 148 different named parameters.
#
# ==== Embedding Layer ====
#
# transformer.wte.weight                                  (50259, 768)
# transformer.wpe.weight                                   (1024, 768)
#
# ==== First Transformer ====
#
# transformer.h.0.ln_1.weight                                   (768,)
# transformer.h.0.ln_1.bias                                     (768,)
# transformer.h.0.attn.c_attn.weight                       (768, 2304)
# transformer.h.0.attn.c_attn.bias                             (2304,)
# transformer.h.0.attn.c_proj.weight                        (768, 768)
# transformer.h.0.attn.c_proj.bias                              (768,)
# transformer.h.0.ln_2.weight                                   (768,)
# transformer.h.0.ln_2.bias                                     (768,)
# transformer.h.0.mlp.c_fc.weight                          (768, 3072)
# transformer.h.0.mlp.c_fc.bias                                (3072,)
# transformer.h.0.mlp.c_proj.weight                        (3072, 768)
# transformer.h.0.mlp.c_proj.bias                               (768,)
#
# ==== Output Layer ====
#
# transformer.ln_f.weight                                       (768,)
# transformer.ln_f.bias                                         (768,)

# %%
# Saving best-practices: if you use defaults names for the model, you can reload it using from_pretrained()

output_dir = './model_save_header/'

# Create output directory if needed
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

print("Saving model to %s" % output_dir)

# Save a trained model, configuration and tokenizer using `save_pretrained()`.
# They can then be reloaded using `from_pretrained()`
model_to_save = model.module if hasattr(model, 'module') else model  # Take care of distributed/parallel training
model_to_save.save_pretrained(output_dir)
tokenizer.save_pretrained(output_dir)

# Good practice: save your training arguments together with the trained model
# torch.save(args, os.path.join(output_dir, 'training_args.bin'))
# Out:
# Saving model to ./model_save/
# ('./model_save/tokenizer_config.json',
#  './model_save/special_tokens_map.json',
#  './model_save/vocab.json',
#  './model_save/merges.txt',
#  './model_save/added_tokens.json')

# %%
# # Load a trained model and vocabulary that you have fine-tuned
output_dir = './model_save_headers/'

#empty cache
torch.cuda.empty_cache()

# Tell pytorch to run this model on the GPU.
device = torch.device("cuda")
model = GPT2LMHeadModel.from_pretrained(output_dir)

model.cuda()

tokenizer = GPT2Tokenizer.from_pretrained(output_dir)
model.to(device)
# Out:
# GPT2LMHeadModel(
#   (transformer): GPT2Model(
#     (wte): Embedding(50259, 768)
#     (wpe): Embedding(1024, 768)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Block(
#         (ln_1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (attn): Attention(
#           (c_attn): Conv1D()
#           (c_proj): Conv1D()
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln_2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (c_fc): Conv1D()
#           (c_proj): Conv1D()
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (lm_head): Linear(in_features=768, out_features=50259, bias=False)
# )

# %%
model.eval()

prompt = """
[Verse 1]
My heart and tongue are fighting, my mind is undecided
It's not like Trump and Biden, it's more like something private
Like when your cousins fighting, one of 'em get excited
You can't just jump the gun and pick a side and jump inside it
"""
"""
Remember, Pontius Pilate hung a God and justified it
The truth is slow 'cause someone's always in a rush to hide it
The lies is golden 'cause the Devil got a touch of Midas
The soul is brighter 'cause the Holy Ghost is ultraviolet
The tongue is violent when the spirit starts to hunger-striking
The thunder lightning makes the heart go under bunkers hiding
The lungs is silent when it hears the footsteps of the giants
And then, the fingertips, they twist up like Poseidon's trident
Remember safety if you ever running from the tight end
Remember Mookie if they ever come to cut the hydrant
They cut the heart out with the tongue, they want it undivided
You better not start, you make a fuss you end up uninvited
"""


generated = torch.tensor(tokenizer.encode(prompt)).unsqueeze(0)
generated = generated.to(device)

print(generated)

sample_outputs = model.generate(
                                generated, 
                                #bos_token_id=random.randint(1,30000),
                                do_sample=True,   
                                top_k=50, 
                                max_length = 300,
                                top_p=0.92, 
                                num_return_sequences=3
                                )

for i, sample_output in enumerate(sample_outputs):
  print("{}: {}\n\n".format(i, tokenizer.decode(sample_output, skip_special_tokens=True)))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# tensor([[  198,    58, 13414,   325,   352,    60,   198,  3666,  2612,   290,
#          11880,   389,  4330,    11,   616,  2000,   318, 39511,   198,  1026,
#            338,   407,   588,  1301,   290, 21010,    11,   340,   338,   517,
#            588,  1223,  2839,   198,  7594,   618,   534, 28706,  4330,    11,
#            530,   286,   705,   368,   651,  6568,   198,  1639,   460,   470,
#            655,  4391,   262,  2485,   290,  2298,   257,  1735,   290,  4391,
#           2641,   340,   198]], device='cuda:0')
# 0:
# [Verse 1]
# My heart and tongue are fighting, my mind is undecided
# It's not like Trump and Biden, it's more like something private
# Like when your cousins fighting, one of 'em get excited
# You can't just jump the gun and pick a side and jump inside it
# And you can't pretend that you really feel it
# 'Cause you can't even fake it
# When you start to hate, you can't even blame it
# A heart filled with anger, it's tearing and killing me
# I'm too young to even know what anger is
# All I ever do is get angry and yell out at me
# And be in the crowd like, "Fuck you!"
# Or yell out at my mother or sister
# 'Cause I don't know what that means
# 'Cause now that's when the real begin
# I can't get sober so I start to drink
# And watch 'em all get on my nerves
# And you wonder why I keep on thinkin'
# 'Cause I know they can't take my medicine
# 'Cause I don't know what that means
# 'Cause the pills are killing me
# I'm going crazy 'til I'm unconscious
# And I can't sleep 'til I'm up
# And I can't breathe 'til I'm down
# Now I'm on the brink of disaster
# [Chorus]
#
#
# 1:
# [Verse 1]
# My heart and tongue are fighting, my mind is undecided
# It's not like Trump and Biden, it's more like something private
# Like when your cousins fighting, one of 'em get excited
# You can't just jump the gun and pick a side and jump inside it
# He said we need more warriors, I said it's urgent
# They say you're too soft and disrespectful
# I said I'm just tryna get what I'm due
# 'Cause I'm a man that's patient and willing
# But when I get angry, I react like an animal
# This what it's like to watch people on TV
# I got a daughter and my momma telling me I'm not her man
# But you know I don't like you I mean I don't love you
# I said "Damn man that's a shame, you can blame Donald
# 'Cause your sister just called and told me I love her"
# But I don't even like to say that, I just really pity her
# 'Cause you know that you were just a daughter
# And you know I'm a selfish person
# I like to take them shots and aim at 'em in they belly
# And I don't know if you can tell me what you meant
# But what I know is that I meant to kill 'em with a passion
# And a passion, and a passion
#
#
#
# 2:
# [Verse 1]
# My heart and tongue are fighting, my mind is undecided
# It's not like Trump and Biden, it's more like something private
# Like when your cousins fighting, one of 'em get excited
# You can't just jump the gun and pick a side and jump inside it
# Like a black man in Vietnam, I'm just looking for the victory
# I'm just looking for a life, yeah, I'll make a wife
# And I'm not afraid to say that I'm with someone else
# I got fantasies of getting a couple million, you heard what I said?
# A couple million, yeah, yeah
# I'm not afraid to say that I'm with someone else
# I got fantasies of getting a couple million, you heard what I said?
# We are one nation under God
# We are not a group of friends, just some of us
# We are one nation under God
#
# [Hook]
# I'm just going through it
# I'm just going through it
#
# [Verse 2]
# I'm just going through it
# I'm just going through it
# I'm just going through it
# Yeah
#
# I just going through it
# Yeah
#
# Yeah
# [Verse 3]
# I'm just gonna head right back to the ghetto
# I'm just gonna head straight
